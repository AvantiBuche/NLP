# %%
text = """The climate has continuously changing for centuries. The global warming happens because the natural rotation of the sun that changes the intensity of sunlight and moving closer to the earth. Another cause of global warming is greenhouse gases. Greenhouse gases are carbon monoxide and sulphur dioxide it trap the solar heats rays and prevent it from escaping from the surface of the earth. This has cause the temperature of the earth increase. Volcanic eruptions are another issue that causes global warming. For instance, a single volcanic eruption will release amount of carbon dioxide and ash to the atmosphere. Once carbon dioxide increase, the temperature of earth increase and greenhouse trap the solar radiations in the earth. Finally, methane is another issue that causes global warming. Methane is also a greenhouse gas. Methane is more effective in trapping heat in the atmosphere that carbon dioxide by 20 times. Usually methane gas can release from many areas. For instance, it can be from cattle, landfill, natural gas, petroleum systems, coal mining, mobile explosion, or industrial waste process."""

# %%
text
# Out:
# 'The climate has continuously changing for centuries. The global warming happens because the natural rotation of the sun that changes the intensity of sunlight and moving closer to the earth. Another cause of global warming is greenhouse gases. Greenhouse gases are carbon monoxide and sulphur dioxide it trap the solar heats rays and prevent it from escaping from the surface of the earth. This has cause the temperature of the earth increase. Volcanic eruptions are another issue that causes global warming. For instance, a single volcanic eruption will release amount of carbon dioxide and ash to the atmosphere. Once carbon dioxide increase, the temperature of earth increase and greenhouse trap the solar radiations in the earth. Finally, methane is another issue that causes global warming. Methane is also a greenhouse gas. Methane is more effective in trapping heat in the atmosphere that carbon dioxide by 20 times. Usually methane gas can release from many areas. For instance, it can be from cattle, landfill, natural gas, petroleum systems, coal mining, mobile explosion, or industrial waste process.'

# %%
import random
import nltk

# %%
n=5

# %%
ngram = {}
words = nltk.word_tokenize(text)

# %%
words
# Out:
# ['The',
#  'climate',
#  'has',
#  'continuously',
#  'changing',
#  'for',
#  'centuries',
#  '.',
#  'The',
#  'global',
#  'warming',
#  'happens',
#  'because',
#  'the',
#  'natural',
#  'rotation',
#  'of',
#  'the',
#  'sun',
#  'that',
#  'changes',
#  'the',
#  'intensity',
#  'of',
#  'sunlight',
#  'and',
#  'moving',
#  'closer',
#  'to',
#  'the',
#  'earth',
#  '.',
#  'Another',
#  'cause',
#  'of',
#  'global',
#  'warming',
#  'is',
#  'greenhouse',
#  'gases',
#  '.',
#  'Greenhouse',
#  'gases',
#  'are',
#  'carbon',
#  'monoxide',
#  'and',
#  'sulphur',
#  'dioxide',
#  'it',
#  'trap',
#  'the',
#  'solar',
#  'heats',
#  'rays',
#  'and',
#  'prevent',
#  'it',
#  'from',
#  'escaping',
#  'from',
#  'the',
#  'surface',
#  'of',
#  'the',
#  'earth',
#  '.',
#  'This',
#  'has',
#  'cause',
#  'the',
#  'temperature',
#  'of',
#  'the',
#  'earth',
#  'increase',
#  '.',
#  'Volcanic',
#  'eruptions',
#  'are',
#  'another',
#  'issue',
#  'that',
#  'causes',
#  'global',
#  'warming',
#  '.',
#  'For',
#  'instance',
#  ',',
#  'a',
#  'single',
#  'volcanic',
#  'eruption',
#  'will',
#  'release',
#  'amount',
#  'of',
#  'carbon',
#  'dioxide',
#  'and',
#  'ash',
#  'to',
#  'the',
#  'atmosphere',
#  '.',
#  'Once',
#  'carbon',
#  'dioxide',
#  'increase',
#  ',',
#  'the',
#  'temperature',
#  'of',
#  'earth',
#  'increase',
#  'and',
#  'greenhouse',
#  'trap',
#  'the',
#  'solar',
#  'radiations',
#  'in',
#  'the',
#  'earth',
#  '.',
#  'Finally',
#  ',',
#  'methane',
#  'is',
#  'another',
#  'issue',
#  'that',
#  'causes',
#  'global',
#  'warming',
#  '.',
#  'Methane',
#  'is',
#  'also',
#  'a',
#  'greenhouse',
#  'gas',
#  '.',
#  'Methane',
#  'is',
#  'more',
#  'effective',
#  'in',
#  'trapping',
#  'heat',
#  'in',
#  'the',
#  'atmosphere',
#  'that',
#  'carbon',
#  'dioxide',
#  'by',
#  '20',
#  'times',
#  '.',
#  'Usually',
#  'methane',
#  'gas',
#  'can',
#  'release',
#  'from',
#  'many',
#  'areas',
#  '.',
#  'For',
#  'instance',
#  ',',
#  'it',
#  'can',
#  'be',
#  'from',
#  'cattle',
#  ',',
#  'landfill',
#  ',',
#  'natural',
#  'gas',
#  ',',
#  'petroleum',
#  'systems',
#  ',',
#  'coal',
#  'mining',
#  ',',
#  'mobile',
#  'explosion',
#  ',',
#  'or',
#  'industrial',
#  'waste',
#  'process',
#  '.']

# %%
   for i in range(len(words)-n):
    gram = ' '.join(words[i:i+n])
    if gram not in ngram.keys():
        ngram[gram] = []
    ngram[gram].append(words[i+n])
    
ngram
# Out:
# {'The climate has continuously changing': ['for'],
#  'climate has continuously changing for': ['centuries'],
#  'has continuously changing for centuries': ['.'],
#  'continuously changing for centuries .': ['The'],
#  'changing for centuries . The': ['global'],
#  'for centuries . The global': ['warming'],
#  'centuries . The global warming': ['happens'],
#  '. The global warming happens': ['because'],
#  'The global warming happens because': ['the'],
#  'global warming happens because the': ['natural'],
#  'warming happens because the natural': ['rotation'],
#  'happens because the natural rotation': ['of'],
#  'because the natural rotation of': ['the'],
#  'the natural rotation of the': ['sun'],
#  'natural rotation of the sun': ['that'],
#  'rotation of the sun that': ['changes'],
#  'of the sun that changes': ['the'],
#  'the sun that changes the': ['intensity'],
#  'sun that changes the intensity': ['of'],
#  'that changes the intensity of': ['sunlight'],
#  'changes the intensity of sunlight': ['and'],
#  'the intensity of sunlight and': ['moving'],
#  'intensity of sunlight and moving': ['closer'],
#  'of sunlight and moving closer': ['to'],
#  'sunlight and moving closer to': ['the'],
#  'and moving closer to the': ['earth'],
#  'moving closer to the earth': ['.'],
#  'closer to the earth .': ['Another'],
#  'to the earth . Another': ['cause'],
#  'the earth . Another cause': ['of'],
#  'earth . Another cause of': ['global'],
#  '. Another cause of global': ['warming'],
#  'Another cause of global warming': ['is'],
#  'cause of global warming is': ['greenhouse'],
#  'of global warming is greenhouse': ['gases'],
#  'global warming is greenhouse gases': ['.'],
#  'warming is greenhouse gases .': ['Greenhouse'],
#  'is greenhouse gases . Greenhouse': ['gases'],
#  'greenhouse gases . Greenhouse gases': ['are'],
#  'gases . Greenhouse gases are': ['carbon'],
#  '. Greenhouse gases are carbon': ['monoxide'],
#  'Greenhouse gases are carbon monoxide': ['and'],
#  'gases are carbon monoxide and': ['sulphur'],
#  'are carbon monoxide and sulphur': ['dioxide'],
#  'carbon monoxide and sulphur dioxide': ['it'],
#  'monoxide and sulphur dioxide it': ['trap'],
#  'and sulphur dioxide it trap': ['the'],
#  'sulphur dioxide it trap the': ['solar'],
#  'dioxide it trap the solar': ['heats'],
#  'it trap the solar heats': ['rays'],
#  'trap the solar heats rays': ['and'],
#  'the solar heats rays and': ['prevent'],
#  'solar heats rays and prevent': ['it'],
#  'heats rays and prevent it': ['from'],
#  'rays and prevent it from': ['escaping'],
#  'and prevent it from escaping': ['from'],
#  'prevent it from escaping from': ['the'],
#  'it from escaping from the': ['surface'],
#  'from escaping from the surface': ['of'],
#  'escaping from the surface of': ['the'],
#  'from the surface of the': ['earth'],
#  'the surface of the earth': ['.'],
#  'surface of the earth .': ['This'],
#  'of the earth . This': ['has'],
#  'the earth . This has': ['cause'],
#  'earth . This has cause': ['the'],
#  '. This has cause the': ['temperature'],
#  'This has cause the temperature': ['of'],
#  'has cause the temperature of': ['the'],
#  'cause the temperature of the': ['earth'],
#  'the temperature of the earth': ['increase'],
#  'temperature of the earth increase': ['.'],
#  'of the earth increase .': ['Volcanic'],
#  'the earth increase . Volcanic': ['eruptions'],
#  'earth increase . Volcanic eruptions': ['are'],
#  'increase . Volcanic eruptions are': ['another'],
#  '. Volcanic eruptions are another': ['issue'],
#  'Volcanic eruptions are another issue': ['that'],
#  'eruptions are another issue that': ['causes'],
#  'are another issue that causes': ['global'],
#  'another issue that causes global': ['warming', 'warming'],
#  'issue that causes global warming': ['.', '.'],
#  'that causes global warming .': ['For', 'Methane'],
#  'causes global warming . For': ['instance'],
#  'global warming . For instance': [','],
#  'warming . For instance ,': ['a'],
#  '. For instance , a': ['single'],
#  'For instance , a single': ['volcanic'],
#  'instance , a single volcanic': ['eruption'],
#  ', a single volcanic eruption': ['will'],
#  'a single volcanic eruption will': ['release'],
#  'single volcanic eruption will release': ['amount'],
#  'volcanic eruption will release amount': ['of'],
#  'eruption will release amount of': ['carbon'],
#  'will release amount of carbon': ['dioxide'],
#  'release amount of carbon dioxide': ['and'],
#  'amount of carbon dioxide and': ['ash'],
#  'of carbon dioxide and ash': ['to'],
#  'carbon dioxide and ash to': ['the'],
#  'dioxide and ash to the': ['atmosphere'],
#  'and ash to the atmosphere': ['.'],
#  'ash to the atmosphere .': ['Once'],
#  'to the atmosphere . Once': ['carbon'],
#  'the atmosphere . Once carbon': ['dioxide'],
#  'atmosphere . Once carbon dioxide': ['increase'],
#  '. Once carbon dioxide increase': [','],
#  'Once carbon dioxide increase ,': ['the'],
#  'carbon dioxide increase , the': ['temperature'],
#  'dioxide increase , the temperature': ['of'],
#  'increase , the temperature of': ['earth'],
#  ', the temperature of earth': ['increase'],
#  'the temperature of earth increase': ['and'],
#  'temperature of earth increase and': ['greenhouse'],
#  'of earth increase and greenhouse': ['trap'],
#  'earth increase and greenhouse trap': ['the'],
#  'increase and greenhouse trap the': ['solar'],
#  'and greenhouse trap the solar': ['radiations'],
#  'greenhouse trap the solar radiations': ['in'],
#  'trap the solar radiations in': ['the'],
#  'the solar radiations in the': ['earth'],
#  'solar radiations in the earth': ['.'],
#  'radiations in the earth .': ['Finally'],
#  'in the earth . Finally': [','],
#  'the earth . Finally ,': ['methane'],
#  'earth . Finally , methane': ['is'],
#  '. Finally , methane is': ['another'],
#  'Finally , methane is another': ['issue'],
#  ', methane is another issue': ['that'],
#  'methane is another issue that': ['causes'],
#  'is another issue that causes': ['global'],
#  'causes global warming . Methane': ['is'],
#  'global warming . Methane is': ['also'],
#  'warming . Methane is also': ['a'],
#  '. Methane is also a': ['greenhouse'],
#  'Methane is also a greenhouse': ['gas'],
#  'is also a greenhouse gas': ['.'],
#  'also a greenhouse gas .': ['Methane'],
#  'a greenhouse gas . Methane': ['is'],
#  'greenhouse gas . Methane is': ['more'],
#  'gas . Methane is more': ['effective'],
#  '. Methane is more effective': ['in'],
#  'Methane is more effective in': ['trapping'],
#  'is more effective in trapping': ['heat'],
#  'more effective in trapping heat': ['in'],
#  'effective in trapping heat in': ['the'],
#  'in trapping heat in the': ['atmosphere'],
#  'trapping heat in the atmosphere': ['that'],
#  'heat in the atmosphere that': ['carbon'],
#  'in the atmosphere that carbon': ['dioxide'],
#  'the atmosphere that carbon dioxide': ['by'],
#  'atmosphere that carbon dioxide by': ['20'],
#  'that carbon dioxide by 20': ['times'],
#  'carbon dioxide by 20 times': ['.'],
#  'dioxide by 20 times .': ['Usually'],
#  'by 20 times . Usually': ['methane'],
#  '20 times . Usually methane': ['gas'],
#  'times . Usually methane gas': ['can'],
#  '. Usually methane gas can': ['release'],
#  'Usually methane gas can release': ['from'],
#  'methane gas can release from': ['many'],
#  'gas can release from many': ['areas'],
#  'can release from many areas': ['.'],
#  'release from many areas .': ['For'],
#  'from many areas . For': ['instance'],
#  'many areas . For instance': [','],
#  'areas . For instance ,': ['it'],
#  '. For instance , it': ['can'],
#  'For instance , it can': ['be'],
#  'instance , it can be': ['from'],
#  ', it can be from': ['cattle'],
#  'it can be from cattle': [','],
#  'can be from cattle ,': ['landfill'],
#  'be from cattle , landfill': [','],
#  'from cattle , landfill ,': ['natural'],
#  'cattle , landfill , natural': ['gas'],
#  ', landfill , natural gas': [','],
#  'landfill , natural gas ,': ['petroleum'],
#  ', natural gas , petroleum': ['systems'],
#  'natural gas , petroleum systems': [','],
#  'gas , petroleum systems ,': ['coal'],
#  ', petroleum systems , coal': ['mining'],
#  'petroleum systems , coal mining': [','],
#  'systems , coal mining ,': ['mobile'],
#  ', coal mining , mobile': ['explosion'],
#  'coal mining , mobile explosion': [','],
#  'mining , mobile explosion ,': ['or'],
#  ', mobile explosion , or': ['industrial'],
#  'mobile explosion , or industrial': ['waste'],
#  'explosion , or industrial waste': ['process'],
#  ', or industrial waste process': ['.']}

# %%
#creating sentences
currentGram = 'the natural rotation of the'

# %%
currentGram
# Out:
# 'the natural rotation of the'

# %%
result = currentGram
for i in range(50):
    if currentGram not in ngram.keys():
        break
    possibilities = ngram[currentGram] # ['for']
    nextitem = possibilities[random.randrange(len(possibilities))]
    result += ' '+nextitem # continuously changing for
    rwords = nltk.word_tokenize(result) #[continuously ,changing, for]
    currentGram = ' '.join(rwords[len(rwords)-n:len(rwords)])
print(result)
# Out:
# the natural rotation of the sun that changes the intensity of sunlight and moving closer to the earth . Another cause of global warming is greenhouse gases . Greenhouse gases are carbon monoxide and sulphur dioxide it trap the solar heats rays and prevent it from escaping from the surface of the earth . This
